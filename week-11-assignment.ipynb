# %% [markdown]
# # Importing Libraries

# %%
import requests
import pandas as pd

# %% [markdown]
# # Configuration of API Key and URL

# %%
api_key = 'chXXh470KwuoGQcvJG1IUbjnBUElrY7w'
url = 'https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json'
params = {
    'api-key': api_key
}

# %% [markdown]
# ## Requesting Data from URL

# %%
response = requests.get(url, params=params)
data = response.json()

# %% [markdown]
# ## Taking out Data from Response of URL

# %%
books = data['results']['books']
df = pd.json_normalize(books)

# %% [markdown]
# ## Print Top 5 Rows of Data

# %%
df.head()
# Out:
#    rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0     1               0              1         0       0     0593422414
# 1     2               1             49         0       0     038554734X
# 2     3               0              1         0       0     1668010410
# 3     4               6              5         0       0     0593243730
# 4     5               5             29         0       0     0593321200
#
#   primary_isbn13      publisher  \
# 0  9780593422410         Putnam
# 1  9780385547345      Doubleday
# 2  9781668010419  Marysue Rucci
# 3  9780593243732           Dial
# 4  9780593321201          Knopf
#
#                                          description price  ...  \
# 0  The second book in the Letty Davenport series....  0.00  ...
# 1  A scientist and single mother living in Califo...  0.00  ...
# 2  Death and trouble loom over a reunion marking ...  0.00  ...
# 3  In a homage to Louisa May Alcott’s “Little Wom...  0.00  ...
# ...
